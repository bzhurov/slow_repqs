# %%
import pygero as gero
gero.plot.use_color('article')
import matplotlib.pyplot as plt
import numpy as np
import glob
# %matplotlib inline

# %%
for f in glob.glob('*.npz'):
    print '------------------------------------'
    print '#', f
    print np.load(f)['script']
# Out:
# ------------------------------------
# # 20161029020310_repqs19reqs_lc_rm_00000_omega0.npz
# # v1n = 'par000'
# # v2n = 'var001'
# data20161029020310_repqs19reqs_lc_rm_00000 = np.load('20161029020310_repqs19reqs_lc_rm_00000.npz')
# v1 = data20161029020310_repqs19reqs_lc_rm_00000['b00000_' + v1n]
# v2 = data20161029020310_repqs19reqs_lc_rm_00000['b00000_' + v2n]
# plt.plot(v1, v2, linestyle = '--', color = 'grey', lw = 6)
# plt.plot(v1[113], v2[113], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
# plt.annotate('LPC', (v1[113], v2[113]), textcoords='offset points', xycoords='data',  xytext=(-30, 15))
# v1 = data20161029020310_repqs19reqs_lc_rm_00000['b00001_' + v1n]
# v2 = data20161029020310_repqs19reqs_lc_rm_00000['b00001_' + v2n]
# plt.plot(v1, v2, linestyle = '-', color = 'grey', lw = 6)
# ...

# %% [markdown]
# Omega = 0.0
# -----------

# %%
# 20161029020310_repqs19reqs_lc_rm_00000_omega0.npz
#plt.figure(figsize=(15, 8))
v1n = 'par000'
v2n = 'var002'
data20161029020310_repqs19reqs_lc_rm_00000 = np.load('20161029020310_repqs19reqs_lc_rm_00000_omega0.npz')
v1 = data20161029020310_repqs19reqs_lc_rm_00000['b00000_' + v1n]
v2 = data20161029020310_repqs19reqs_lc_rm_00000['b00000_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'grey', lw = 6)
plt.plot(v1[113], v2[113], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 1, zorder = 1000)
plt.annotate('LPC', (v1[113], v2[113]), textcoords='offset points', xycoords='data',  xytext=(-30, 15))
v1 = data20161029020310_repqs19reqs_lc_rm_00000['b00001_' + v1n]
v2 = data20161029020310_repqs19reqs_lc_rm_00000['b00001_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'grey', lw = 6)

#Steady state
data20161106165323_repqs19reqs_ss_rm_00000 = np.load('20161106165323_repqs19reqs_ss_rm_00000_omega0.npz')
v1 = data20161106165323_repqs19reqs_ss_rm_00000['b00000_' + v1n]
v2 = data20161106165323_repqs19reqs_ss_rm_00000['b00000_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'black', lw = 3)
plt.plot(v1[27], v2[27], marker = 's', markersize = 12, markeredgewidth = 0, color = 'g', markeredgecolor = 'g', alpha = 1, zorder = 1000)
plt.annotate('HB', (v1[27], v2[27]), textcoords='offset points', xycoords='data',  xytext=(20, 15))
v1 = data20161106165323_repqs19reqs_ss_rm_00000['b00001_' + v1n]
v2 = data20161106165323_repqs19reqs_ss_rm_00000['b00001_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'black', lw = 3)
plt.xlim(0, 0.015)
plt.ylim(0.5, 1e2)
plt.yscale('log')
plt.xlabel('$r_m$')
plt.ylabel('$M_2$')
plt.tight_layout()
plt.savefig('fig1a.png', dpi = 300)

# %% [markdown]
# omega = 1
# ---------

# %%
# 20161103231735_repqs19reqs_ss_rm_00000_omega1.npz
v1n = 'par000'
v2n = 'var002'
data20161103231735_repqs19reqs_ss_rm_00000 = np.load('20161103231735_repqs19reqs_ss_rm_00000_omega1.npz')
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'black', lw = 3)
plt.plot(v1[31], v2[31], marker = 's', markersize = 12, markeredgewidth = 0, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('HB', (v1[31], v2[31]), textcoords='offset points', xycoords='data',  xytext=(20, 15))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'black', lw = 3)
plt.plot(v1[76], v2[76], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[76], v2[76]), textcoords='offset points', xycoords='data',  xytext=(20, 15))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'black', lw = 3)
plt.plot(v1[1513], v2[1513], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[1513], v2[1513]), textcoords='offset points', xycoords='data',  xytext=(20, -5))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'black', lw = 3)

datarepqs19reqs_20161026102604_lc_00000 = np.load('repqs19reqs_20161026102604.lc_00000_omega1.npz')
v1 = datarepqs19reqs_20161026102604_lc_00000['b00000_' + v1n]
v2 = datarepqs19reqs_20161026102604_lc_00000['b00000_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'grey', lw = 6)
plt.plot(v1[141], v2[141], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LPC', (v1[141], v2[141]), textcoords='offset points', xycoords='data',  xytext=(20, 5))
v1 = datarepqs19reqs_20161026102604_lc_00000['b00001_' + v1n]
v2 = datarepqs19reqs_20161026102604_lc_00000['b00001_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'grey', lw = 6)
plt.xlim(0.0, 0.03)
plt.ylim(0.5, 200)
plt.yscale('log')
plt.xlabel('$r_m$')
plt.ylabel('$M_2$')
plt.tight_layout()
plt.savefig('fig1b.png', dpi = 300)

# %% [markdown]
# 3 genes together
# ----------------

# %%
#1st gene
plt.figure(figsize=(10,8))
v1n = 'par000'
v2n = 'var015'
data20161103231735_repqs19reqs_ss_rm_00000 = np.load('20161103231735_repqs19reqs_ss_rm_00000_omega1.npz')
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v2n]
l1, = plt.plot(v1, v2, linestyle = '-', color = 'r', lw = 3)
plt.plot(v1[31], v2[31], marker = 's', markersize = 12, markeredgewidth = 0, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
#plt.annotate('HB', (v1[31], v2[31]), textcoords='offset points', xycoords='data',  xytext=(-30, 15))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'r', lw = 3)
plt.plot(v1[76], v2[76], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[76], v2[76]), textcoords='offset points', xycoords='data',  xytext=(20, 0))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'r', lw = 3)
plt.plot(v1[1513], v2[1513], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[1513], v2[1513]), textcoords='offset points', xycoords='data',  xytext=(-20, 0))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'r', lw = 3)

#2d gene
v1n = 'par000'
v2n = 'var016'
data20161103231735_repqs19reqs_ss_rm_00000 = np.load('20161103231735_repqs19reqs_ss_rm_00000_omega1.npz')
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v2n]
l2, = plt.plot(v1, v2, linestyle = '-', color = 'b', lw = 3)
plt.plot(v1[31], v2[31], marker = 's', markersize = 12, markeredgewidth = 0, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('HB', (v1[31], v2[31]), textcoords='offset points', xycoords='data',  xytext=(-30, 15))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'b', lw = 3)
plt.plot(v1[76], v2[76], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[76], v2[76]), textcoords='offset points', xycoords='data',  xytext=(20, 0))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'b', lw = 3)
plt.plot(v1[1513], v2[1513], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[1513], v2[1513]), textcoords='offset points', xycoords='data',  xytext=(-20, 0))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'b', lw = 3)

#3d gene
v1n = 'par000'
v2n = 'var018'
data20161103231735_repqs19reqs_ss_rm_00000 = np.load('20161103231735_repqs19reqs_ss_rm_00000_omega1.npz')
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00000_' + v2n]
l3, = plt.plot(v1, v2, linestyle = '-', color = 'g', lw = 3)
plt.plot(v1[31], v2[31], marker = 's', markersize = 12, markeredgewidth = 0, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
#plt.annotate('HB', (v1[31], v2[31]), textcoords='offset points', xycoords='data',  xytext=(-30, 15))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00001_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'g', lw = 3)
plt.plot(v1[76], v2[76], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[76], v2[76]), textcoords='offset points', xycoords='data',  xytext=(20, 0))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00002_' + v2n]
plt.plot(v1, v2, linestyle = '--', color = 'g', lw = 3)
plt.plot(v1[1513], v2[1513], marker = 'x', markersize = 12, markeredgewidth = 4, color = 'g', markeredgecolor = 'g', alpha = 0.5, zorder = 1000)
plt.annotate('LP', (v1[1513], v2[1513]), textcoords='offset points', xycoords='data',  xytext=(-20, 0))
v1 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v1n]
v2 = data20161103231735_repqs19reqs_ss_rm_00000['b00003_' + v2n]
plt.plot(v1, v2, linestyle = '-', color = 'g', lw = 3)

plt.xlim(0.0, 0.03)
plt.ylim(0.001, 21)
plt.yscale('log')
plt.xlabel('$r_m$')
plt.ylabel('$G_i$')
plt.legend([l1, l2, l3], ['$G_1$', '$G_2$', '$G_3$'], loc = 3)
plt.tight_layout()
plt.savefig('fig1c.png', dpi = 300)
